# %% [markdown]
# # Day 3: 11 - Role Intelligence
#
# Required skill taxonomy per role.

# %%
import pandas as pd
roles_df = pd.read_csv("../data/processed/role_skills.csv")
print(roles_df.to_string())
