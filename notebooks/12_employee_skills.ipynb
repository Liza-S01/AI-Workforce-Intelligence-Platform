# %% [markdown]
# # Day 3: 12 - Employee Skills Table
#
# Employee skill inventory with proficiency levels.

# %%
import pandas as pd
skills_df = pd.read_csv("../data/processed/employee_skills.csv")
print(f"Total employee skill records: {len(skills_df)}")
skills_df.head(10)
